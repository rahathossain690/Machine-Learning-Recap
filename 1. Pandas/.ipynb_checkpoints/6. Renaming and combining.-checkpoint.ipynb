# %%
import pandas as pd

pd.set_option('max_rows', 5)
df = pd.read_csv('games.csv')

# %%
df.rename(columns={'victory_status': 'status'})
# Out:
#              id  rated    created_at  last_move_at  turns     status winner  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13  outoftime  white
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16     resign  black
# ...         ...    ...           ...           ...    ...        ...    ...
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109     resign  white
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78       mate  black
#
#       increment_code      white_id  white_rating   black_id  black_rating  \
# 0               15+2      bourgris          1500       a-00          1191
# 1               5+10          a-00          1322  skinnerua          1261
# ...              ...           ...           ...        ...           ...
# 20056           10+0  marcodisogno          1360   jamboger          1227
# 20057           10+0      jamboger          1235      ffbob          1339
#
#                                                    moves opening_eco  \
# 0      d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1      d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# ...                                                  ...         ...
# 20056  e4 d6 d4 Nf6 e5 dxe5 dxe5 Qxd1+ Kxd1 Nd5 c4 Nb...         B07
# 20057  d4 d5 Bf4 Na6 e3 e6 c3 Nf6 Nf3 Bd7 Nbd2 b5 Bd3...         D00
#
#                                  opening_name  opening_ply
# 0            Slav Defense: Exchange Variation            5
# 1      Nimzowitsch Defense: Kennedy Variation            4
# ...                                       ...          ...
# 20056                            Pirc Defense            4
# 20057         Queen's Pawn Game: Mason Attack            3
#
# [20058 rows x 16 columns]

# %%
df.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                    id  rated    created_at  last_move_at  turns  \
# firstEntry   TZJHLljE  False  1.504210e+12  1.504210e+12     13
# secondEntry  l1NXvwaE   True  1.504130e+12  1.504130e+12     16
# ...               ...    ...           ...           ...    ...
# 20056        b0v4tRyF   True  1.499696e+12  1.499697e+12    109
# 20057        N8G2JHGG   True  1.499643e+12  1.499644e+12     78
#
#             victory_status winner increment_code      white_id  white_rating  \
# firstEntry       outoftime  white           15+2      bourgris          1500
# secondEntry         resign  black           5+10          a-00          1322
# ...                    ...    ...            ...           ...           ...
# 20056               resign  white           10+0  marcodisogno          1360
# 20057                 mate  black           10+0      jamboger          1235
#
#               black_id  black_rating  \
# firstEntry        a-00          1191
# secondEntry  skinnerua          1261
# ...                ...           ...
# 20056         jamboger          1227
# 20057            ffbob          1339
#
#                                                          moves opening_eco  \
# firstEntry   d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# secondEntry  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# ...                                                        ...         ...
# 20056        e4 d6 d4 Nf6 e5 dxe5 dxe5 Qxd1+ Kxd1 Nd5 c4 Nb...         B07
# 20057        d4 d5 Bf4 Na6 e3 e6 c3 Nf6 Nf3 Bd7 Nbd2 b5 Bd3...         D00
#
#                                        opening_name  opening_ply
# firstEntry         Slav Defense: Exchange Variation            5
# secondEntry  Nimzowitsch Defense: Kennedy Variation            4
# ...                                             ...          ...
# 20056                                  Pirc Defense            4
# 20057               Queen's Pawn Game: Mason Attack            3
#
# [20058 rows x 16 columns]

# %%
# left = canadian_youtube.set_index(['title', 'trending_date'])
# right = british_youtube.set_index(['title', 'trending_date'])

# left.join(right, lsuffix='_CAN', rsuffix='_UK')

## This will join DataFrames based on indexes(same)
