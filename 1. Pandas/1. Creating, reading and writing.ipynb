# %%
# !pip3 install pandas
# Out:
# ...
#     100% |████████████████████████████████| 9.5MB 155kB/s ta 0:00:011    85% |███████████████████████████▍    | 8.1MB 1.3MB/s eta 0:00:02
# ...
#     100% |████████████████████████████████| 13.4MB 104kB/s ta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/70/94/784178ca5dd892a98f113cdd923372024dc04b8d40abe77ca76b5fb90ca6/pytz-2021.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl
# ...

# %%
import pandas as pd

# %%
# Dataframe is a table containing data
# now it is crearing DataFrame from python dictionary

pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Hello': ['nice', 'very nice'], 'Hi': ['good', 'very good']})
# Out:
#        Hello         Hi
# 0       nice       good
# 1  very nice  very good

# %%
# using index
pd.DataFrame({'Physics': [98, 62], 'Chemistry': [88, 99]}, index=['Rahat', 'Hossain'])
# Out:
#          Physics  Chemistry
# Rahat         98         88
# Hossain       62         99

# %%
# DataFrame is a table whereas Series is a list
pd.Series([1, 2, 3, 4, 5], index=['A', 'B', 'C', None, 'E'])
# Out:
# A      1
# B      2
# C      3
# NaN    4
# E      5
# dtype: int64

# %%
# Reading data
# Data is written in CSV File 
# # Product A,Product B,Product C,
# # 30,21,9,
# # 35,34,1,
# # 41,11,11
df = pd.read_csv('demo_data.csv')
df
# Out:
#    Product A  Product B  Product C
# 0         30         21          9
# 1         35         34          1
# 2         41         11         11

# %%
#shape
df.shape
# Out:
# (3, 3)

# %%
# metadata
df.describe()
# Out:
#        Product A  Product B  Product C
# count   3.000000   3.000000   3.000000
# mean   35.333333  22.000000   7.000000
# std     5.507571  11.532563   5.291503
# min    30.000000  11.000000   1.000000
# 25%    32.500000  16.000000   5.000000
# 50%    35.000000  21.000000   9.000000
# 75%    38.000000  27.500000  10.000000
# max    41.000000  34.000000  11.000000

# %%
# head or tail
df.head() # df.tail()
# Out:
#    Product A  Product B  Product C
# 0         30         21          9
# 1         35         34          1
# 2         41         11         11

# %%
# df comes with lot of functionalities too
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
# use Shift + Tab to get documentation of a function in jupyter notebook
df.mode() # try it here
# Out:
#    Product A  Product B  Product C
# 0         30         11          1
# 1         35         21          9
# 2         41         34         11
